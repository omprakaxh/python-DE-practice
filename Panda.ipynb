# %% [markdown]
# <a href="https://colab.research.google.com/github/omprakaxh/python-DE-practice/blob/master/Panda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chiptole.tsv'
chipo = pd.read_csv(url,sep='\t')

# %%
chipo.head(10)
#To see the first n column's use head function
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
chipo.shape[0]
# shape give's the number of entries
# Out:
# 4622

# %%
chipo.shape[1]
# Out:
# 5

# %%
chipo.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
chipo.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
quantity = chipo.groupby('item_name')
quantity = quantity.sum()
quantity = quantity.sort_values(['quantity'],ascending=False)
quantity.head(1)
# Out:
#               order_id  quantity  \
# item_name
# Chicken Bowl    713926       761
#
#                                              choice_description  \
# item_name
# Chicken Bowl  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...
#
#                                                      item_price
# item_name
# Chicken Bowl  $16.98 $10.98 $11.25 $8.75 $8.49 $11.25 $8.75 ...

# %%
choice = chipo.groupby('choice_description').sum()
choice = choice.sort_values(['quantity'],ascending=False)
choice.head(1)
# Out:
#                     order_id  quantity  \
# choice_description
# [Diet Coke]           123455       159
#
#                                                             item_name  \
# choice_description
# [Diet Coke]         Canned SodaCanned SodaCanned Soda6 Pack Soft D...
#
#                                                            item_price
# choice_description
# [Diet Coke]         $2.18 $1.09 $1.09 $6.49 $2.18 $1.25 $1.09 $6.4...

# %%
total = chipo.quantity.sum()
total
# Out:
# np.int64(4972)

# %%
chipo.item_price.dtype
# Out:
# dtype('O')

# %%
dollarizer = lambda x: float(x[1:-1])
chipo.item_price = chipo.item_price.apply(dollarizer)

# %%
chipo.item_price.dtype
# Out:
# dtype('float64')

# %%
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
kaasu = chipo.quantity * chipo.item_price
kaasu = round(kaasu.sum(),2)
kaasu
#
# Out:
# np.float64(39237.02)

# %%
chipo.order_id.value_counts().count()
# Out:
# np.int64(1834)

# %%
average = chipo.quantity * chipo.item_price
average = average.sum() / 1834
average
# Out:
# np.float64(21.39423118865867)

# %%
chipo.item_name.value_counts().count()
# Out:
# np.int64(50)
