# %%
import pandas as pd

# %%
df = pd.read_csv("employees_updates.csv")

# %%
df.groupby('City')['Salary'].sum()
# Out:
# City
# Bangalore    80000
# Chennai      55000
# Delhi        60000
# Hyderabad    70000
# Mumbai       50000
# Pune         45000
# Name: Salary, dtype: int64

# %%
#df.groupby('City')['Name'].count()
df['City'].value_counts()
# Out:
# City
# Mumbai       1
# Delhi        1
# Pune         1
# Bangalore    1
# Chennai      1
# Hyderabad    1
# Name: count, dtype: int64

# %%
df.groupby("City")["Salary"].max().sort_values(ascending=False)
# Out:
# City
# Bangalore    80000
# Hyderabad    70000
# Delhi        60000
# Chennai      55000
# Mumbai       50000
# Pune         45000
# Name: Salary, dtype: int64

# %%
df.groupby('City')['Salary'].agg(['mean' , 'sum'])
# Out:
#               mean    sum
# City
# Bangalore  80000.0  80000
# Chennai    55000.0  55000
# Delhi      60000.0  60000
# Hyderabad  70000.0  70000
# Mumbai     50000.0  50000
# Pune       45000.0  45000
